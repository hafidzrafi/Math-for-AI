# %%
import numpy as np
import matplotlib.pyplot as plt
from vector import visualize

# %%
vec = np.array([13, - 5])
norm = np.linalg.norm(vec)
vec_unit = vec / norm

# %%
visualize([vec, vec_unit], ["red", "blue"])
